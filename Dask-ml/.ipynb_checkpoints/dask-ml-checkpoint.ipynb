# %% [markdown]
# 1. Preprocessing
# 2. Cross validation
# 3. Linear regression
# 4. KMeans Clustering
# 5. Pipelining
# 6. Hyper parameters

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline  # regular scikit-learn pipeline
from sklearn.pipeline import Pipeline  # regular scikit-learn pipeline


import dask 
import dask.dataframe as dd
from dask_ml.preprocessing import Categorizer, DummyEncoder, StandardScaler
from dask_ml.model_selection import train_test_split
from dask_ml.linear_model import LogisticRegression, LinearRegression
from dask_ml.decomposition import PCA
from dask_ml.cluster import KMeans

# %%
# https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package

ddf = dd.read_csv("weatherAUS.csv", dtype={'Humidity3pm': 'float64',
       'Humidity9am': 'float64',
       'WindGustSpeed': 'float64',
       'WindSpeed3pm': 'float64',
       'WindSpeed9am': 'float64'})
ddf.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %% [markdown]
# # Data Prepocessing

# %% [markdown]
# The first process step in building a machine learning model is data cleaning. The data we have here is not very complex which makes data cleaning easier. In production quality ML model this is the most time consuming step.
#
# Data cleaning maily involves:
# 1. Remove any unnecessary observations from your dataset
# 2. Remove redundant informations
# 3. Remove duplicate informations
# 4. Remove structural errors in data collection
# 5. Remove unwanted outliers - outliers can result in overfitting
# 6. Handle missing data:
#     * Remove observations with values missing
#     * Infer the missing values

# %% [markdown]
# In this case we are taking the easiest method to address missing values. We are removing any dataframe row that has missing values. This is not always advicable as we are lossing a lot of information and in the end we end up not getting the entire picture.
#
# Inferring data is also not always a good ideas as we maybe adding some bias to the inference.

# %%
ddf_clean = ddf.dropna() 
ddf_clean.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 6050  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 6052  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 6053  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 6054  2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 6049         SSW           48.0        ENE  ...        20.0         13.0
# 6050           S           37.0        SSE  ...        30.0          8.0
# 6052         NNE           46.0        NNE  ...        42.0         22.0
# 6053         WNW           31.0        WNW  ...        37.0         22.0
# 6054         WNW           35.0         NW  ...        19.0         15.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 6049       1006.3       1004.4       2.0       5.0     26.6     33.4
# 6050       1012.9       1012.1       1.0       1.0     20.3     27.0
# 6052       1012.3       1009.2       1.0       6.0     28.7     34.9
# 6053       1012.7       1009.1       1.0       5.0     29.1     35.6
# 6054       1010.7       1007.4       1.0       6.0     33.6     37.6
#
#       RainToday  RainTomorrow
# 6049         No            No
# 6050         No            No
# 6052         No            No
# 6053         No            No
# 6054         No            No
#
# [5 rows x 23 columns]

# %%
shape = ddf_clean.shape
print(shape)
# Out:
# (Delayed('int-88c87923-7c00-4241-80f6-1f4f5b95584d'), 23)

# %%
print(type(shape[0]))
print(type(shape[1]))
# Out:
# <class 'dask.delayed.Delayed'>
# <class 'int'>

# %% [markdown]
# As you can see the columns are immediatly computed while the rows are not. We have invoke compute get the result.

# %%
shape[0].compute()
# Out:
# 56420

# %%
ddf_clean.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# Here, we are trying to predict the temperature based at 3PM.
# 1. We divide the data frame into target and features.
#     * Target is the value we are trying to predict
#     * Feature are the data points used to predict the target
# 2.  We remove all the features we deem unncessary

# %%
# Target
ddf_target = ddf_clean['Temp3pm']

# %% [markdown]
# Data usually have numerical data and catogorical data.
# 1. Categorical data groups information (usuallytext) with similar characteristics
# 2. Numerical data expresses information in the form of numbers
#
# Most machine learning algorithms cannot handle categorical variables unless it is converted to numerical data. This process is called encoding.

# %% [markdown]
# Ideally all catogorical data should be converted to numerical data. In this case we remove some all catogorical data other than 'RainToday' and 'RainTomorrow'.

# %%
# Features
ddf_features = ddf_clean.drop(columns=['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'Temp3pm'])

# %%
ddf_features.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049     17.9     35.2       0.0         12.0      12.3           48.0
# 6050     18.4     28.9       0.0         14.8      13.0           37.0
# 6052     19.4     37.6       0.0         10.8      10.6           46.0
# 6053     21.9     38.4       0.0         11.4      12.2           31.0
# 6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 6049           6.0          20.0         20.0         13.0       1006.3
# 6050          19.0          19.0         30.0          8.0       1012.9
# 6052          30.0          15.0         42.0         22.0       1012.3
# 6053           6.0           6.0         37.0         22.0       1012.7
# 6054          17.0          13.0         19.0         15.0       1010.7
#
#       Pressure3pm  Cloud9am  Cloud3pm  Temp9am RainToday RainTomorrow
# 6049       1004.4       2.0       5.0     26.6        No           No
# 6050       1012.1       1.0       1.0     20.3        No           No
# 6052       1009.2       1.0       6.0     28.7        No           No
# 6053       1009.1       1.0       5.0     29.1        No           No
# 6054       1007.4       1.0       6.0     33.6        No           No

# %%
shape = ddf_features.shape
print(shape)
# Out:
# (Delayed('int-60a18cbc-89cf-4bed-ae89-1b8a928de37f'), 17)

# %%
shape[0].compute()
# Out:
# 56420

# %%
ddf_features.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustSpeed    float64
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %% [markdown]
# There are two types of cataogirical data in Dask
# 1. Known: categories are known statically (from the metadata)
# 2. Unknown: categories are not known statically (from the metadata)

# %% [markdown]
# **categorize()** function in meta scans the entire data find the different catogories in a feature.

# %%
ddf_features = ddf_features.categorize()

# %%
ddf_features.dtypes
# Out:
# MinTemp           float64
# MaxTemp           float64
# Rainfall          float64
# Evaporation       float64
# Sunshine          float64
# WindGustSpeed     float64
# WindSpeed9am      float64
# WindSpeed3pm      float64
# Humidity9am       float64
# Humidity3pm       float64
# Pressure9am       float64
# Pressure3pm       float64
# Cloud9am          float64
# Cloud3pm          float64
# Temp9am           float64
# RainToday        category
# RainTomorrow     category
# dtype: object

# %% [markdown]
# We can verify if the catogries of a feature are known as shown below

# %%
ddf_features.RainTomorrow.cat.known
# Out:
# True

# %% [markdown]
# Encoding is the method of converting catogorical values into numerical values (and vice versa). There are two here we use **Dummy Encoding**. Each catogory end up geting a binary value.

# %%
de = DummyEncoder()
ddf_features_preproc = de.fit_transform(ddf_features.categorize())

# %%
ddf_features_preproc.head().reset_index()
# Out:
#    index  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0   6049     17.9     35.2       0.0         12.0      12.3           48.0
# 1   6050     18.4     28.9       0.0         14.8      13.0           37.0
# 2   6052     19.4     37.6       0.0         10.8      10.6           46.0
# 3   6053     21.9     38.4       0.0         11.4      12.2           31.0
# 4   6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0           6.0          20.0         20.0         13.0       1006.3
# 1          19.0          19.0         30.0          8.0       1012.9
# 2          30.0          15.0         42.0         22.0       1012.3
# 3           6.0           6.0         37.0         22.0       1012.7
# 4          17.0          13.0         19.0         15.0       1010.7
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  RainToday_No  RainToday_Yes  \
# 0       1004.4       2.0       5.0     26.6             1              0
# 1       1012.1       1.0       1.0     20.3             1              0
# 2       1009.2       1.0       6.0     28.7             1              0
# 3       1009.1       1.0       5.0     29.1             1              0
# 4       1007.4       1.0       6.0     33.6             1              0
#
#    RainTomorrow_No  RainTomorrow_Yes
# 0                1                 0
# 1                1                 0
# 2                1                 0
# 3                1                 0
# 4                1                 0

# %% [markdown]
# ## Normalization
#
# It is a good practice to normalize the data. It is especially useful when different features have different value range.

# %%
scaler = StandardScaler()
scalar_norm = scaler.fit(ddf_features_preproc)

# %%
scalar_norm.mean_
# Out:
# array([1.34647696e+01, 2.42192060e+01, 2.13039702e+00, 5.50313541e+00,
#        7.73562566e+00, 4.08773662e+01, 1.56672279e+01, 1.97867777e+01,
#        6.58741227e+01, 4.96019851e+01, 1.01723951e+03, 1.01479558e+03,
#        4.24170507e+00, 4.32651542e+00, 1.82049610e+01, 7.79120879e-01,
#        2.20879121e-01, 7.79741227e-01, 2.20258773e-01])

# %%
ddf_features_norm = scaler.fit_transform(ddf_features_preproc)

# %%
ddf_features_norm.head()
# Out:
#        MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049  0.691208  1.575298 -0.303702     1.757691  1.214537       0.534126
# 6050  0.769131  0.671504 -0.303702     2.515216  1.400800      -0.290764
# 6052  0.924976  1.919600 -0.303702     1.433038  0.762183       0.384146
# 6053  1.314588  2.034368 -0.303702     1.595364  1.187928      -0.740704
# 6054  1.673032  2.407362 -0.303702     1.541255  0.176784      -0.440744
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 6049     -1.162355      0.025055    -2.477924    -1.812261    -1.583303
# 6050      0.400721     -0.092452    -1.937767    -2.059824    -0.628068
# 6052      1.723325     -0.562482    -1.289578    -1.366647    -0.714907
# 6053     -1.162355     -1.620048    -1.559657    -1.366647    -0.657014
# 6054      0.160248     -0.797496    -2.531940    -1.713236    -0.946479
#
#       Pressure3pm  Cloud9am  Cloud3pm   Temp9am  RainToday_No  RainToday_Yes  \
# 6049    -1.513002 -0.801428  0.254411  1.278186      0.532445      -0.532445
# 6050    -0.392322 -1.158937 -1.256603  0.318980      0.532445      -0.532445
# 6052    -0.814396 -1.158937  0.632165  1.597921      0.532445      -0.532445
# 6053    -0.828951 -1.158937  0.254411  1.658823      0.532445      -0.532445
# 6054    -1.076373 -1.158937  0.632165  2.343970      0.532445      -0.532445
#
#       RainTomorrow_No  RainTomorrow_Yes
# 6049         0.531485         -0.531485
# 6050         0.531485         -0.531485
# 6052         0.531485         -0.531485
# 6053         0.531485         -0.531485
# 6054         0.531485         -0.531485

# %% [markdown]
# ## Corelation Matrix
#
# Correlation is often used in machine learning to identify multicollinearity, which is when two or more predictor variables are highly correlated with each other. Multicollinearity can adversily affect the accuracy of predictive models.
#
# * The coefficients become very sensitive to small changes in the model.
# * Multicollinearity reduces the precision of the estimated coefficients, which weakens the statistical power of your regression model.
#
# Multicollinearity can be addressed removing one of the correlated variables

# %%
corr_matrix = ddf_features_norm.corr(method='pearson', min_periods=None, numeric_only='__no_default__', split_every=False)

# %%
corr_matrix.compute()
# Out:
#                    MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp           1.000000  0.749687  0.110800     0.506764  0.076087
# MaxTemp           0.749687  1.000000 -0.069981     0.650964  0.463913
# Rainfall          0.110800 -0.069981  1.000000    -0.077239 -0.246379
# Evaporation       0.506764  0.650964 -0.077239     1.000000  0.369250
# Sunshine          0.076087  0.463913 -0.246379     0.369250  1.000000
# WindGustSpeed     0.118054  0.035531  0.106308     0.209566 -0.052422
# WindSpeed9am      0.108522 -0.008171  0.050584     0.193154 -0.013842
# WindSpeed3pm      0.137273  0.012266  0.044112     0.124345  0.029200
# Humidity9am      -0.174991 -0.495781  0.263625    -0.554232 -0.500343
# Humidity3pm       0.070827 -0.448116  0.277625    -0.422436 -0.629299
# Pressure9am      -0.475661 -0.350980 -0.180606    -0.297319  0.043330
# Pressure3pm      -0.495577 -0.451691 -0.137302    -0.325954 -0.020632
# Cloud9am          0.106177 -0.263634  0.217169    -0.199809 -0.677939
# Cloud3pm          0.042173 -0.257752  0.191433    -0.202366 -0.702022
# Temp9am           0.906295  0.893387  0.013713     0.593122  0.289038
# RainToday_No     -0.048953  0.221810 -0.550515     0.218079  0.328904
# RainToday_Yes     0.048953 -0.221810  0.550515    -0.218079 -0.328904
# RainTomorrow_No  -0.087428  0.147467 -0.254342     0.130002  0.453407
# RainTomorrow_Yes  0.087428 -0.147467  0.254342    -0.130002 -0.453407
#
#                   WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp                0.118054      0.108522      0.137273    -0.174991
# MaxTemp                0.035531     -0.008171      0.012266    -0.495781
# Rainfall               0.106308      0.050584      0.044112     0.263625
# Evaporation            0.209566      0.193154      0.124345    -0.554232
# Sunshine              -0.052422     -0.013842      0.029200    -0.500343
# WindGustSpeed          1.000000      0.608852      0.685236    -0.193410
# WindSpeed9am           0.608852      1.000000      0.502226    -0.236795
# WindSpeed3pm           0.685236      0.502226      1.000000    -0.100626
# Humidity9am           -0.193410     -0.236795     -0.100626     1.000000
# Humidity3pm           -0.042653     -0.058449      0.031843     0.685697
# Pressure9am           -0.430363     -0.201518     -0.293155     0.114575
# Pressure3pm           -0.383683     -0.155484     -0.252095     0.172972
# Cloud9am               0.088129      0.034908      0.068224     0.438962
# Cloud3pm               0.131590      0.062507      0.041475     0.348707
# Temp9am                0.085520      0.053749      0.114043    -0.423598
# RainToday_No          -0.146276     -0.083125     -0.085627    -0.379451
# RainToday_Yes          0.146276      0.083125      0.085627     0.379451
# RainTomorrow_No       -0.233158     -0.083904     -0.088862    -0.271033
# RainTomorrow_Yes       0.233158      0.083904      0.088862     0.271033
#
#                   Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# MinTemp              0.070827    -0.475661    -0.495577  0.106177  0.042173
# MaxTemp             -0.448116    -0.350980    -0.451691 -0.263634 -0.257752
# Rainfall             0.277625    -0.180606    -0.137302  0.217169  0.191433
# Evaporation         -0.422436    -0.297319    -0.325954 -0.199809 -0.202366
# Sunshine            -0.629299     0.043330    -0.020632 -0.677939 -0.702022
# WindGustSpeed       -0.042653    -0.430363    -0.383683  0.088129  0.131590
# WindSpeed9am        -0.058449    -0.201518    -0.155484  0.034908  0.062507
# WindSpeed3pm         0.031843    -0.293155    -0.252095  0.068224  0.041475
# Humidity9am          0.685697     0.114575     0.172972  0.438962  0.348707
# Humidity3pm          1.000000    -0.063454     0.024109  0.509223  0.510996
# Pressure9am         -0.063454     1.000000     0.961538 -0.150427 -0.166334
# Pressure3pm          0.024109     0.961538     1.000000 -0.081791 -0.103173
# Cloud9am             0.509223    -0.150427    -0.081791  1.000000  0.614380
# Cloud3pm             0.510996    -0.166334    -0.103173  0.614380  1.000000
# Temp9am             -0.151614    -0.443410    -0.500509 -0.109591 -0.107885
# RainToday_No        -0.385440     0.186848     0.104103 -0.297794 -0.272034
# RainToday_Yes        0.385440    -0.186848    -0.104103  0.297794  0.272034
# RainTomorrow_No     -0.455358     0.254816     0.230418 -0.323972 -0.388574
# RainTomorrow_Yes     0.455358    -0.254816    -0.230418  0.323972  0.388574
#
#                    Temp9am  RainToday_No  RainToday_Yes  RainTomorrow_No  \
# MinTemp           0.906295     -0.048953       0.048953        -0.087428
# MaxTemp           0.893387      0.221810      -0.221810         0.147467
# Rainfall          0.013713     -0.550515       0.550515        -0.254342
# Evaporation       0.593122      0.218079      -0.218079         0.130002
# Sunshine          0.289038      0.328904      -0.328904         0.453407
# WindGustSpeed     0.085520     -0.146276       0.146276        -0.233158
# WindSpeed9am      0.053749     -0.083125       0.083125        -0.083904
# WindSpeed3pm      0.114043     -0.085627       0.085627        -0.088862
# Humidity9am      -0.423598     -0.379451       0.379451        -0.271033
# Humidity3pm      -0.151614     -0.385440       0.385440        -0.455358
# Pressure9am      -0.443410      0.186848      -0.186848         0.254816
# Pressure3pm      -0.500509      0.104103      -0.104103         0.230418
# Cloud9am         -0.109591     -0.297794       0.297794        -0.323972
# Cloud3pm         -0.107885     -0.272034       0.272034        -0.388574
# Temp9am           1.000000      0.096946      -0.096946         0.018179
# RainToday_No      0.096946      1.000000      -1.000000         0.309098
# RainToday_Yes    -0.096946     -1.000000       1.000000        -0.309098
# RainTomorrow_No   0.018179      0.309098      -0.309098         1.000000
# RainTomorrow_Yes -0.018179     -0.309098       0.309098        -1.000000
#
#                   RainTomorrow_Yes
# MinTemp                   0.087428
# MaxTemp                  -0.147467
# Rainfall                  0.254342
# Evaporation              -0.130002
# Sunshine                 -0.453407
# WindGustSpeed             0.233158
# WindSpeed9am              0.083904
# WindSpeed3pm              0.088862
# Humidity9am               0.271033
# Humidity3pm               0.455358
# Pressure9am              -0.254816
# Pressure3pm              -0.230418
# Cloud9am                  0.323972
# Cloud3pm                  0.388574
# Temp9am                  -0.018179
# RainToday_No             -0.309098
# RainToday_Yes             0.309098
# RainTomorrow_No          -1.000000
# RainTomorrow_Yes          1.000000

# %%
f, ax = plt.subplots(figsize=(12, 10))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr_matrix, annot=True, mask = mask, cmap=cmap)
# Out:
# <Axes: >

# %% [markdown]
# Ideally we should remove one of the higly correlated feature or combine those together. For the time being we doing neither.

# %% [markdown]
# ## Principal Component Analysis

# %%
pca = PCA(n_components=3)
pca.fit(ddf_features_norm.to_dask_array(lengths=True))
PCA(copy=True, iterated_power='auto', n_components=3, random_state=None, svd_solver='auto', tol=0.0, whiten=False)
# Out:
# PCA(iterated_power='auto', n_components=3)

# %%
pca.fit_transform(ddf_features_norm.to_dask_array(lengths=True))
# Out:
# dask.array<mul, shape=(56420, 3), dtype=float64, chunksize=(56420, 3), chunktype=numpy.ndarray>

# %%
pca.get_feature_names_out()
# Out:
# array(['pca0', 'pca1', 'pca2'], dtype=object)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.28446169 0.22573935 0.10772273]

# %%
pca.components_
# Out:
# array([[-1.09450104e-01, -2.89157519e-01,  1.86381155e-01,
#         -2.56730854e-01, -3.41587561e-01,  2.48311757e-02,
#         -5.76861193e-03,  6.17338609e-03,  3.19165424e-01,
#          3.33569571e-01,  3.95612243e-04,  4.19304259e-02,
#          2.75802519e-01,  2.75769084e-01, -2.11523055e-01,
#         -2.68501179e-01,  2.68501179e-01, -2.55394764e-01,
#          2.55394764e-01],
#        [ 3.58820536e-01,  2.65302040e-01,  1.43490952e-01,
#          2.34951931e-01, -3.55876935e-02,  2.72903212e-01,
#          1.84842136e-01,  2.12991724e-01, -9.60177477e-02,
#          4.47060403e-02, -3.95534158e-01, -3.90000702e-01,
#          1.01635441e-01,  1.09003617e-01,  3.33954396e-01,
#         -1.38331761e-01,  1.38331761e-01, -1.97511459e-01,
#          1.97511459e-01],
#        [-2.98598924e-01, -2.58707840e-01, -7.42222144e-02,
#         -2.93954742e-02,  5.51614618e-02,  4.96333572e-01,
#          4.83795442e-01,  4.65914032e-01, -1.54193398e-01,
#         -1.42838226e-01,  1.32225523e-03,  3.71399752e-02,
#         -8.54957189e-02, -5.46307683e-02, -2.82154332e-01,
#          1.80527526e-02, -1.80527526e-02,  2.11635399e-02,
#         -2.11635399e-02]])

# %% [markdown]
# # Cross validation
# Cross-validation is a method for evaluating ML models by training several ML models on subsets of the data and evaluating anonther subset of the data. The adavantages of cross validation are :
#
# 1. Identify Overfitting
# 2. Comparisson between different models
# 3. Hyperparameter tuning
# 4. Efficienncy : Allows the use of data for both training and validation

# %%
#Divide into learning and test set

X_train, X_test, y_train, y_test = train_test_split(ddf_features_norm, ddf_target, shuffle=False)

# %%
X_train.compute().head()
X_test.compute().head()
# Out:
#        MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6072  1.345757  1.503568  0.922284     0.837840  1.241146       0.684106
# 6081  2.202905  2.306941 -0.303702     2.406998  0.842010       1.209036
# 6105  0.691208  1.374455 -0.303702     0.783731  1.134709      -1.265633
# 6111  0.800300  0.040283 -0.303702     2.623433  0.043738       0.984066
# 6118  0.940560  1.030152 -0.303702     0.350860  0.735574       0.384146
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 6072     -0.561172     -0.562482    -1.073515    -1.317135    -1.250418
# 6081      0.160248     -1.267526    -1.829736    -1.465673    -0.989899
# 6105     -0.320699     -1.502541    -2.207846    -1.515185    -0.367549
# 6111      0.761431      0.495085    -1.073515    -1.416160    -0.179397
# 6118      1.242378     -0.092452    -0.641389    -0.772496    -0.049137
#
#       Pressure3pm  Cloud9am  Cloud3pm   Temp9am  RainToday_No  RainToday_Yes  \
# 6072    -0.945385 -0.801428  0.632165  1.506568     -1.878128       1.878128
# 6081    -1.120036  0.271097 -0.878850  2.100362      0.532445      -0.532445
# 6105    -0.261334 -1.516445 -1.256603  0.882323      0.532445      -0.532445
# 6111     0.117078  1.343622 -1.256603  0.060147      0.532445      -0.532445
# 6118    -0.057574 -1.158937 -1.256603  0.547362      0.532445      -0.532445
#
#       RainTomorrow_No  RainTomorrow_Yes
# 6072         0.531485         -0.531485
# 6081         0.531485         -0.531485
# 6105         0.531485         -0.531485
# 6111         0.531485         -0.531485
# 6118         0.531485         -0.531485

# %%
y_train.compute().head()
y_test.compute().head()
# Out:
# 6072    33.2
# 6081    38.5
# 6105    32.4
# 6111    22.9
# 6118    30.2
# Name: Temp3pm, dtype: float64

# %%
y_train_array = y_train.to_dask_array(lengths=True)
X_train_array = X_train.to_dask_array(lengths=True)

# %%
X_train_array
# Out:
# dask.array<values, shape=(50750, 19), dtype=float64, chunksize=(50750, 19), chunktype=numpy.ndarray>

# %% [markdown]
# # Linear Regression
#
# Linear regression tries to find the optimal W<sub>1</sub>, W<sub>2</sub>, W<sub>3</sub>, W<sub>4</sub>, so that we can predict the value of Y for the user supplied X<sub>1</sub>, X<sub>2</sub>, X<sub>3</sub>.
#
# $$
#   Y(X_1, X_2, X_3) = W_1 * X_1 + W_2 * X_2 + W_3 * X_3 + W_4
# $$

# %%
lr = LinearRegression(solver_kwargs={"normalize":False})

# %%
lr.fit(X_train_array, y_train_array)
# Out:
# LinearRegression(solver_kwargs={'normalize': False})

# %%
y_test_array = y_test.to_dask_array(lengths=True)
X_test_array = X_test.to_dask_array(lengths=True)

# %%
print(lr.score(X_test_array, y_test_array))
# Out:
# 0.980999894315764

# %%
predicted_value = lr.predict(X_test_array[0, :].reshape(1, 19))

# %%
predicted_value.compute()
# Out:
# array([32.76180384])

# %%
original_value = y_test_array[0]

# %%
original_value.compute()
# Out:
# 33.2

# %% [markdown]
# # K-Means Clustering

# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing()
X, y = data.data, data.target
feature_names = data.feature_names

# %%
mat = np.column_stack((X, y))
df = pd.DataFrame(mat, columns=np.append(feature_names, 'MedianValue'))
df.shape
# Out:
# (20640, 9)

# %%
ddf = dd.from_pandas(df, npartitions=10).dropna()
ddf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedianValue
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
sns.scatterplot(data = df, x = 'Longitude', y = 'Latitude', hue = 'MedianValue')
# Out:
# <Axes: xlabel='Longitude', ylabel='Latitude'>

# %%
ddf_features = ddf.drop(columns=['MedianValue'])
ddf_target = ddf[['MedianValue']]

X_train, X_test, y_train, y_test = train_test_split(ddf_features, ddf_target, test_size=0.2)
# Out:
# /home/joseph/.local/lib/python3.8/site-packages/dask_ml/model_selection/_split.py:462: FutureWarning: The default value for 'shuffle' must be specified when splitting DataFrames. In the future DataFrames will automatically be shuffled within blocks prior to splitting. Specify 'shuffle=True' to adopt the future behavior now, or 'shuffle=False' to retain the previous behavior.
#   warnings.warn(

# %%
pipe = Pipeline([('reduce_dim', PCA()), 
                 ('cluster', KMeans(n_clusters = 3, random_state = 0, n_init='auto'))
                ])

# %%
kmeans = pipe.fit(X_train.to_dask_array(lengths=True))

# %%
pipe['cluster'].labels_.compute()
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
train_score = pipeline.score(X_train, y_train)
print('R2 score on the training set:', np.round(train_score, 5))

test_score = pipeline.score(X_test, y_test)
print('R2 score on the test set:', np.round(test_score, 5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-7a562d118f16> in <module>
# ----> 1 train_score = pipe.score(X_train, y_train)
#       2 print('R2 score on the training set:', np.round(train_score, 5))
#       3
#       4 test_score = pipeline.score(X_test, y_test)
#       5 print('R2 score on the test set:', np.round(test_score, 5))
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/_available_if.py in __get__(self, obj, owner)
#      29             # delegate only on instances, not the classes.
#      30             # this is to allow access to the docstrings.
# ---> 31             if not self.check(obj):
#      32                 raise attr_err
#      33             out = MethodType(self.fn, obj)
#
# ~/.local/lib/python3.8/site-packages/sklearn/pipeline.py in check(self)
#      42     def check(self):
#      43         # raise original `AttributeError` if `attr` does not exist
# ---> 44         getattr(self._final_estimator, attr)
#      45         return True
#      46
#
# AttributeError: 'KMeans' object has no attribute 'score'

# %%
sns.scatterplot(data = X_train, x = 'Longitude', y = 'Latitude', hue = pipe['cluster'].labels_)
# Out:
# <Axes: xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# # Hyperparameter optimization
